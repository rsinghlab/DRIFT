# %%
import scanpy as sc
from src.DRIFT import DRIFT

# %% [markdown]
# ## Running DRIFT to obtain diffused spatial transcriptomics input

# %%
file_path = "data/MERMPH_4.h5ad" #Give your data file location here

adata = sc.read_h5ad(file_path)
adata.var_names_make_unique()

diffused_adata = DRIFT(adata, t = 2)

# %% [markdown]
# diffused_adata.X now contains the diffused inputs and can be used for any downstream analysis

# %%
print(diffused_adata.shape)
# Out:
# (5488, 155)
